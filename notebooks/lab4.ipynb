# %% [markdown]
# # Tutorial 04: Data Processing Techniques
#
# **Lecture 4 topics:** CSV I/O, pandas Series & DataFrames, data preprocessing.

# %% [markdown]
# ## Step 0: Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# # Part A — Core Lab Tasks
#
# Follow the steps from *Laboratory Session 4* using `../Data/Market.csv`.

# %% [markdown]
# ### Task 1 — Load the dataset and inspect it
#
# Load `Market.csv` into a pandas DataFrame and display its content.

# %% [markdown]
# ### Task 2 — Data cleaning
#
# Identify and fix:
# - Empty / missing data
# - Unnecessary duplicates
# - Wrong formats (e.g. `housing_median_age = 52.0001`)
# - Wrong values (e.g. inconsistent `ocean_proximity` labels: `NEAR O` vs `NEAR OCEAN`)
#
# Store the result in `df_clean`.

# %% [markdown]
# ### Task 3 — Descriptive statistics for `median_house_value`
#
# Compute **mean**, **median**, and **range** (max − min).

# %% [markdown]
# ### Task 4 — NumPy array and chart comparison
#
# Extract `median_house_value` into a NumPy array. Plot it as a **line chart**, **box plot**, and **bar chart** (three separate figures is fine for this task).
#
# **Question:** Which chart type best represents this data? Briefly explain why. *(Hint: think about whether the row order is meaningful.)*

# %% [markdown]
# **Answer:**

# %% [markdown]
# ---
# # Part B — Additional Practice (pandas / matplotlib)
#
# Use `df_clean` from Task 2 for all exercises below.

# %% [markdown]
# ### Task 5 — pandas Series (Lecture 4, Part 2)
#
# Create a pandas **Series** whose:
# - **index** = each `ocean_proximity` category
# - **values** = mean `median_house_value` for that category
# - **name** = `'AvgHousePrice'`
#
# Print the Series, then create a second Series with values converted to **thousands** (divide by 1000).

# %% [markdown]
# ### Task 6 — Multi-panel dashboard with `plt.subplots`
#
# Create **one figure** with a **2×2 grid** of axes:
#
# | Position | Chart |
# |----------|-------|
# | Top-left | Histogram of `median_income` |
# | Top-right | Box plot of `housing_median_age` |
# | Bottom-left | Bar chart of mean `median_house_value` by `ocean_proximity` |
# | Bottom-right | Scatter plot: `longitude` vs `latitude`, point size ∝ `median_house_value` |
#
# Add a **super title** and individual axis titles. Use `plt.tight_layout()`.

# %% [markdown]
# ### Task 7 — Nested layout with `fig.subfigures`
#
# Use **`fig.subfigures(1, 2)`** to split the figure into a **left** and **right** panel:
#
# - **Left subfigure:** histogram of `median_house_value` with a title
# - **Right subfigure:** two stacked plots —
#   - top: scatter of `median_income` vs `median_house_value`
#   - bottom: bar chart of record count per `ocean_proximity`
#
# > `subfigures` (matplotlib ≥ 3.4) let you create nested figure regions — useful for report-style layouts.

# %% [markdown]
# ### Task 8 — `groupby` aggregation table
#
# Build a summary DataFrame grouped by `ocean_proximity` with columns:
# `count`, `mean`, `median`, `min`, `max` for `median_house_value`.
#
# Display the table and plot a **grouped bar chart** comparing mean vs median side by side.

# %% [markdown]
# ### Task 9 — Filtering and sorting
#
# 1. Select rows where `median_house_value` > 300,000 using **boolean indexing**.
# 2. Select rows where `ocean_proximity == 'INLAND'` using **`df.query()`**.
# 3. Sort all rows by `median_income` descending and show the top 5.

# %%
# 1. Boolean indexing

# %%
# 2. query()

# %%
# 3. sort_values

# %% [markdown]
# ### Task 10 — Save and reload cleaned data (Lecture 4, CSV I/O)
#
# 1. Export `df_clean` to `Data/Market_clean.csv` (without the pandas index).
# 2. Reload it with `pd.read_csv`.
# 3. Wrap the load in a **`try/except`** block to handle a missing file gracefully.
